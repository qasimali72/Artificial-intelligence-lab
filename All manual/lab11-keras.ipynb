# %%
import pandas as pd

# %%
df=pd.read_csv('dataset.csv')

# %%
y=df[['e1','e2']]

# %%
X=df.drop(['e1','e2'],axis=1)

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(2, input_dim=3, activation='sigmoid'))  # Hidden layer with 2 units
model.add(Dense(2, activation='sigmoid'))  # Output layer with 2 units

# %%
model.compile(loss='mean_squared_error', optimizer='sgd', metrics=['accuracy'])

# %%
# Train the model
model.fit(X, y, epochs=5)

# Evaluate the model
loss, accuracy = model.evaluate(X, y)
print('Accuracy:', accuracy)
# Out:
# Epoch 1/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.5000 - loss: 0.2966
# Epoch 2/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5000 - loss: 0.2965
# Epoch 3/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5000 - loss: 0.2964
# Epoch 4/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5000 - loss: 0.2964
# Epoch 5/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5000 - loss: 0.2963
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5000 - loss: 0.2962
# Accuracy: 0.5
